# %%
Планирование и анализ требований

    1. Цели приложения:
- Разработать приложение, которое демонстрирует эффективное использование асинхронного программирования для решения различных типов задач.
- Сравнить производительность и удобство использования подходов asyncio, threading и multiprocessing.
- Предоставить рекомендации по выбору подхода в зависимости от типа задач.

    2. Функциональные требования:
1. Реализация задач для сравнения:
   - I/O-bound задача: Обработка сетевых запросов (например, загрузка данных с веб-сайтов).
   - CPU-bound задача: Выполнение вычислительно интенсивных операций (например, вычисление факториала больших чисел).
   - Блокирующая задача: Чтение/запись файлов или другие операции, которые занимают много времени.

2. Поддержка трех подходов:
   - Реализация каждой задачи с использованием asyncio, threading и multiprocessing.

3. Сравнение производительности:
   - Измерение времени выполнения задач для каждого подхода.
   - Сравнение потребления ресурсов (память, процессор).

4. Интерфейс приложения:
   - Простой интерфейс для запуска задач и отображения результатов.
   - Возможность выбора типа задачи и подхода.

    3. Нефункциональные требования:
1. Производительность:
   - Приложение должно быть максимально эффективным в использовании ресурсов.
   - Результаты сравнения должны быть воспроизводимыми.

2. Масштабируемость:
   - Приложение должно поддерживать выполнение большого количества задач одновременно.

3. Простота использования:
   - Код должен быть легко читаемым и понятным.
   - Документация должна быть предоставлена для каждого подхода.

4. Кроссплатформенность:
   - Приложение должно работать на различных операционных системах (Windows, Linux, macOS).

    4. Анализ требований (таблица):

# %%
import pandas as pd

data = {
    'Требование': ['I/O-bound задача', 'CPU-bound задача', 'Блокирующая задача', 'Производительность', 'Простота реализации', 'Потребление ресурсов'],
    'Asyncio': ['Идеально подходит', 'Не подходит', 'Подходит (с использованием `loop.run_in_executor`)', 'Высокая для I/O-bound задач', 'Средняя (требует понимания корутин)', 'Низкое'],
    'TYhreading': ['Подходит', 'Не подходит (из-за GIL)', 'Подходит', 'Средняя для I/O-bound задач ', 'Высокая', 'Среднее'],
    'Multiprocessing': ['Не подходит', 'Идеально подходит', 'Подходит', 'Высокая для CPU-bound задач', 'Средняя (требует понимания процессов)', 'Высокое']
}

df = pd.DataFrame(data)

df
# Out:
#              Требование                                            Asyncio  \
# 0      I/O-bound задача                                  Идеально подходит
# 1      CPU-bound задача                                        Не подходит
# 2    Блокирующая задача  Подходит (с использованием `loop.run_in_execut...
# 3    Производительность                        Высокая для I/O-bound задач
# 4   Простота реализации                Средняя (требует понимания корутин)
# 5  Потребление ресурсов                                             Низкое
#
#                      TYhreading                        Multiprocessing
# 0                      Подходит                            Не подходит
# 1       Не подходит (из-за GIL)                      Идеально подходит
# 2                      Подходит                               Подходит
# 3  Средняя для I/O-bound задач             Высокая для CPU-bound задач
# 4                       Высокая  Средняя (требует понимания процессов)
# ...
